# %% [markdown]
# <a href="https://colab.research.google.com/github/lvlanson/uebersterblichkeit/blob/master/Sachsen_Ubersterblichkeit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/lvlanson/uebersterblichkeit/master/BL_2016_2020.csv"



df = pd.read_csv(url, sep=",", skiprows=8)

columns = list(df.columns)

columns[1] = "Jahr"
columns[2] = "Bundesland"

df.columns = columns

df_sachsen = df.loc[df["Bundesland"] == "Sachsen "]

df_sachsen.head()
# Out:
#     Nr.  Jahr Bundesland  01.01.  ...  29.12.  30.12.  31.12.  Insgesamt
# 13   14  2020   Sachsen      154  ...     NaN     NaN     NaN        NaN
# 29   30  2019   Sachsen      160  ...   143.0   173.0   166.0    54 946
# 45   46  2018   Sachsen      161  ...   134.0   130.0   137.0    56 290
# 61   62  2017   Sachsen      183  ...   151.0   156.0   170.0    54 689
# 77   78  2016   Sachsen      169  ...   162.0   178.0   173.0    53 330
#
# [5 rows x 370 columns]

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

data = []
years = []

for row in range(df_sachsen.shape[0]):
  trace = go.Scatter(x=df_sachsen.columns[3:-1].values, 
                     y=df_sachsen.iloc[row:row+1,3:-1].values[0],
                     name=str(df_sachsen.Jahr.values[row]))
  if df_sachsen.Jahr.values[row] != 2020:
    years.append(df_sachsen.iloc[row:row+1,3:-1].values[0])

  data.append(trace)
fig = go.Figure(data=data)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2b9d3808-af74-4b48-b151-76b8d5166cb1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2b9d3808-af74-4b48-b151-76b8d5166cb1")) {
#                     Plotly.newPlot(
#                         '2b9d3808-af74-4b48-b151-76b8d5166cb1',
# ...

# %%
import copy

mit = []
for year in years:
  mittel = 0
  counter = 0
  for day in year:
    if isinstance(day, int):
      mittel += day
      counter += 1
  mittel /= counter
  mit.append(mittel)


years_fix = copy.deepcopy(years)
for i,year in enumerate(years_fix):
  for j,day in enumerate(year):
    if isinstance(day, str):
      years_fix[i][j] = mit[i]

y_mit = []

for y_1, y_2, y_3, y_4 in zip(*years_fix):
  y_mit.append((y_1+y_2+y_3+y_4)/4)

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

data = []
years = []

row = 0

trace = go.Scatter(x=df_sachsen.columns[3:-1].values, 
                   y=df_sachsen.iloc[row:row+1,3:-1].values[0],
                   name=str(df_sachsen.Jahr.values[row]))
data.append(trace)

trace = go.Scatter(x=df_sachsen.columns[3:-1].values, 
                   y=y_mit,
                   name="Durchschnitt 2016-2019")
data.append(trace)
fig = go.Figure(data=data)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e45d5525-d8fd-412a-ab07-7b3d81a53171" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e45d5525-d8fd-412a-ab07-7b3d81a53171")) {
#                     Plotly.newPlot(
#                         'e45d5525-d8fd-412a-ab07-7b3d81a53171',
# ...

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/lvlanson/uebersterblichkeit/master/BL_2016_2020(2).csv"

df = pd.read_csv(url, sep=",", skiprows=8)

columns = list(df.columns)

columns[0] = "Jahr"

df.columns = columns

# %%
df
# Out:
#    Jahr   01.01.   02.01.   03.01.  ...   29.12.   30.12.   31.12.  Insgesamt
# 0  2021   3 503    3 477    3 375   ...      NaN      NaN      NaN        NaN
# 1  2020   2 690    2 813    2 761   ...   3 724    3 759    3 544    984 965
# 2  2019   2 639    2 642    2 610   ...   2 523    2 620    2 707    939 520
# 3  2018   2 665    2 760    2 870   ...   2 573    2 453    2 579    954 874
# 4  2017   2 912    3 085    2 923   ...   2 570    2 712    2 758    932 263
# 5  2016   2 558    2 422    2 522   ...   2 751    2 834    2 796    910 899
#
# [6 rows x 368 columns]

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

data = []
years = []

for row in range(df.shape[0]):
  trace = go.Scatter(x=df.columns[3:-1].values, 
                     y=df.iloc[row:row+1,3:-1].values[0],
                     name=str(df.Jahr.values[row]))
  if df.Jahr.values[row] != 2020:
    years.append(df.iloc[row:row+1,3:-1].values[0])

  data.append(trace)
fig = go.Figure(data=data)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="db61495d-b964-4469-af77-e72a5a0da46d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("db61495d-b964-4469-af77-e72a5a0da46d")) {
#                     Plotly.newPlot(
#                         'db61495d-b964-4469-af77-e72a5a0da46d',
# ...

# %%
import copy

mit = []
for year in years:
  mittel = 0
  counter = 0
  for day in year:
    if isinstance(day, str):
      date = day.replace(" ", "")
      if date.isnumeric():
        mittel += int(date)
        counter += 1
    
  mittel /= counter
  mit.append(mittel)


years_fix = copy.deepcopy(years)
for i,year in enumerate(years_fix):
  for j,day in enumerate(year):
    if isinstance(day, str):
      years_fix[i][j] = mit[i]

y_mit = []

for y_1, y_2, y_3, y_4, y_5 in zip(*years_fix):
  y_mit.append((y_1+y_2+y_3+y_4+y_5)/5)

print(len(y_mit))
# Out:
# 364

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

data = []
years = []

row = 0

trace = go.Scatter(x=df.columns[3:-1].values, 
                   y=df.iloc[row:row+1,3:-1].values[0],
                   name=str(df.Jahr.values[row]))
data.append(trace)

trace = go.Scatter(x=df.columns[3:-1].values, 
                   y=y_mit,
                   name="Durchschnitt 2016-2019")
data.append(trace)
fig = go.Figure(data=data)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c8202ef2-82a4-4eea-bd1b-b408471a7870" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c8202ef2-82a4-4eea-bd1b-b408471a7870")) {
#                     Plotly.newPlot(
#                         'c8202ef2-82a4-4eea-bd1b-b408471a7870',
# ...
